# %%
import pandas as pd
import numpy as np

import nltk
from nltk.tokenize import word_tokenize

# %%
# nltk.download()

# %%
violations_section = pd.read_csv("../data/violations_section.csv")
violations_TCA = pd.read_csv("../data/violations_TCA.csv")
violations_MCL = pd.read_csv("../data/violations_MCL.csv")
violations_description_id = pd.read_csv("../data/violations_description_id.csv")
violations_remainder = pd.read_csv("../data/violations_remainder.csv")

# %%
violations_list = [violations_section, violations_TCA, violations_MCL, violations_description_id, violations_remainder]

# %%
for violation in violations_list:
    assert 'Unnamed: 0' in violation.columns

# %%
for violation in violations_list:
    violation.set_index('Unnamed: 0', inplace=True)
    violation.index.rename('Original_Index', inplace=True)
    
    violation['remedial'].replace(np.nan, '', regex=True, inplace=True)

# %%
violations_description_id.head()
# Out:
#                                                                id  type desc  \
# Original_Index
# 15              (B). It is unlawful for any person to dispose ...   NaN    N
# 438             he or she shall serve notice of the risk and t...   NaN  NaN
# 439                     tree at the expense of the property owner   NaN    N
# 707             human occupation or use, upon failure or refus...   NaN  NaN
# 708             remove or demolish, such dwelling or structure...   NaN    N
#
#                 text remedial
# Original_Index
# 15               NaN        1
# 438              NaN
# 439              NaN        2
# 707              NaN
# 708              NaN        2

# %%
violations_description_id['text'] = violations_description_id['id'].values

# %%
violations_description_id.head()
# Out:
#                                                                id  type desc  \
# Original_Index
# 15              (B). It is unlawful for any person to dispose ...   NaN    N
# 438             he or she shall serve notice of the risk and t...   NaN  NaN
# 439                     tree at the expense of the property owner   NaN    N
# 707             human occupation or use, upon failure or refus...   NaN  NaN
# 708             remove or demolish, such dwelling or structure...   NaN    N
#
#                                                              text remedial
# Original_Index
# 15              (B). It is unlawful for any person to dispose ...        1
# 438             he or she shall serve notice of the risk and t...
# 439                     tree at the expense of the property owner        2
# 707             human occupation or use, upon failure or refus...
# 708             remove or demolish, such dwelling or structure...        2

# %%
for violation in violations_list:
    violation.drop('id', axis='columns', inplace=True)
    
    violation['type'].replace(np.nan, '', regex=True, inplace=True)
    violation['desc'].replace(np.nan, '', regex=True, inplace=True)
    violation['text'].replace(np.nan, '', regex=True, inplace=True)

# %%
violations_section.head()
# Out:
#                       type                            desc  \
# Original_Index
# 0                  BANNERS                         Banners
# 1               BGMATOWNER  Proper Maintenance Req - Owner
# 2                BLDGMAINT          Proper Maintenance Req
# 3               BLDGPERMIT        Building Permit Required
# 4                BLDGSCOPE          Scope of Building Code
#
#                                                              text  \
# Original_Index
# 0               Section 17.32.060 & 17.32.070 -  Banners: Bann...
# 1               Section 16.16.030 (B) - Proper maintenance req...
# 2               Section 16.16.030 (A) - Proper maintenance req...
# 3               Section 16.28.010 - Building Permit Required: ...
# 4               Section 16.16.020 (B) - The provisions of this...
#
#                         remedial
# Original_Index
# 0                   CAAZ_BANNERS
# 1               CAAH_BG_MATOWNER
# 2                CAAH_BLDG_MAINT
# 3               CAAB_BLDG_PERMIT
# 4                CAAH_BLDG_SCOPE

# %%
violations_TCA.head()
# Out:
#                          type                                   desc  \
# Original_Index
# 106                   LANDREG         Landlord Registration Required
# 376             CAAR_LAND_REG         LANDLORD REGISTRATION REQUIRED
# 807                BT575101A2  Not Manufacturer and Wholesale Retail
# 808                BT575101A3  Not Wholesale and Manufacturer Retail
# 809                BT575103A1   Operating without county city permit
#
#                                                              text  \
# Original_Index
# 106             Tennessee Code Annotated (TCA) 66-28-101 - Fai...
# 376             Tennessee Code Annotated (TCA) 66-28-101 - Fai...
# 807             T.C.A 57-5-101(a)(2): Except as otherwise prov...
# 808             T.C.A 57-5-101(a)(3): Except as otherwise prov...
# 809             T.C.A 57-5-103(a)(1): It is unlawful to operat...
#
#                      remedial
# Original_Index
# 106             CAAR_LAND_REG
# 376
# 807
# 808
# 809

# %%
violations_MCL.head()
# Out:
#                       type                        desc  \
# Original_Index
# 481               CAGA_DEX               DOG EXCREMENT
# 482             CAGB_HAZ_W             HAZARDOUS WASTE
# 483               CAGC_GCL      GARBAGE CONTAINER LIDS
# 484                CAGD_ID             ILLEGAL DUMPING
# 485               CAGE_LPR  LITTER ON PRIVATE PROPERTY
#
#                                                              text remedial
# Original_Index
# 481             MCL Chapter 8.04.180 – Removal of Excrement.  ...
# 482             MCL Chapter 10.20.150 - Hazardous, pathogenic ...
# 483             MCL Chapter 10.20.160 – Container Requirements...
# 484             MCL Chapter 10.20.320 – Illegal Dumping.  It i...
# 485             MCL Chapter 10.24.070 - Litter on private prop...

# %%
violations_description_id.head()
# Out:
#                type desc                                               text  \
# Original_Index
# 15                     N  (B). It is unlawful for any person to dispose ...
# 438                       he or she shall serve notice of the risk and t...
# 439                    N          tree at the expense of the property owner
# 707                       human occupation or use, upon failure or refus...
# 708                    N  remove or demolish, such dwelling or structure...
#
#                remedial
# Original_Index
# 15                    1
# 438
# 439                   2
# 707
# 708                   2

# %%
violations_remainder.head()
# Out:
#                      type                                      desc  \
# Original_Index
# 126              MVENVEND                            Mobile Vending
# 196             TRASHCANS                                Trash Cans
# 209             SWVIOLPTP  Violations - Post Construction Treatment
# 210              SWVIOLWQ      Violations for Water Quality Impacts
# 211              SWENVCRT           Environmental Court Proceedings
#
#                                                              text  \
# Original_Index
# 126             Ordinance BL2006-1283 - Mobile Vendor: The ped...
# 196             Ordinance 89-826 - Trash Cans: Refuse containe...
# 209                                                   See SW Code
# 210                                                   See SW Code
# 211                                                   See SW Code
#
#                          remedial
# Original_Index
# 126             CAAZ_MVEN_VENDING
# 196               CAAH_TRASH_CANS
# 209
# 210
# 211

# %%
master_violations = pd.concat(violations_list)

# %%
master_violations
# Out:
#                       type                                      desc  \
# Original_Index
# 0                  BANNERS                                   Banners
# 1               BGMATOWNER            Proper Maintenance Req - Owner
# 2                BLDGMAINT                    Proper Maintenance Req
# 3               BLDGPERMIT                  Building Permit Required
# 4                BLDGSCOPE                    Scope of Building Code
# 5               BOARDINGRQ                     Boarding Requirements
# 6                 BOARDVAC              Boarding of Vacant Buildings
# 7                   CARROW               Vehicle In The Right-Of-Way
# 8                 CERTCOMP        Certificate of Compliance Required
# 9                  CERTOCC         Certificate of Occupancy Required
# 10               CHICKFARM  Chickens and Other Domestic Farm Animals
# 11              CONSIGSALE                          Consignment Sale
# 12               CROWDEDFM           Overcrowding – Unrelated Adults
# 13                 CROWDGH                 Overcrowding – Group Home
# 14               DUMPDESIG               Dumping in permitted places
# 16                DUMPSTER   Hours of Collection & Dumpster Required
# 17                 ECSYSHZ                 Electrical System Hazards
# 18              ECSYSHZCRT           Electrical System Certification
# 19               ELECEAREC                    Electrical Receptacles
# 20                  ELECEQ                     Electrical Equipment
# 21              ELECEQLIGH              Electrical Lighting Fixtures
# 22                 ELECFAC            Electrical Facilities Required
# 23              ELECSVCPAN                  Electrical Service Panel
# 24                  EXPARK   Exterior Prop Area – Vehicles – Parking
# 25                  EXTACC     Exterior Prop Area – Acces Structures
# 26                EXTBAHAT    Exterior of Bldgs – Basement Hatchways
# 27                  EXTBAL         Exterior of Buildings - Balconies
# 28               EXTCHIMTW   Exterior of Bldgs – Chimneys and Towers
# 29                  EXTDEC             Exterior of Buildings – Decks
# 30                 EXTDECF   Exterior of Bldgs – Decorative Features
# ...                    ...                                       ...
# 888                   BBR8  Special Event bonafide charity political
# 889                   BBR9                   All owners and partners
# 890                  BBR10                               No delivery
# 891                  BBR12                     Permittee responsible
# 892                  BBR13               Lease or Ownership required
# 893                 BBR14A                    All applicants over 21
# 894                 BBR14B                          Ascertaining age
# 896                  BBR15                   Special Event Approvals
# 903                  BBR16                    Payment Types Accepted
# 904                  BBR17                 Crimes of moral turpitude
# 906                  BBR18                         Health Department
# 907                  BBR19                              Fire Marshal
# 909                  BBR21                         Surrender permits
# 910                  BBR22               Complaints filed in writing
# 911                  BBR24                       Old or New Location
# 912                  BBR26                Applications 10 days prior
# 915                  BBR28       Cannot surrender to avoid penalties
# 916                  BBR29  Cannot temporary permits with complaints
# 918                  BBR30                             Grandfathered
# 921                  BBR31                         Expanded premises
# 922                  BBR32                           Caterer Permits
# 923                  BBR34                        Standard penalties
# 925                  BBR33                Past violations considered
# 926                  BBR35                    LLC equals corporation
# 927                  BBR36            No motions for reconsideration
# 928                  BBR37                     Special Event Permits
# 929                  BBR38                          Suspension Rules
# 930                  BBR40                Deny permit after 6 months
# 932                  BBR41          No permit issued with complaints
# 933                  BBR39               Sports Authority Facilities
#
#                                                              text  \
# Original_Index
# 0               Section 17.32.060 & 17.32.070 -  Banners: Bann...
# 1               Section 16.16.030 (B) - Proper maintenance req...
# 2               Section 16.16.030 (A) - Proper maintenance req...
# 3               Section 16.28.010 - Building Permit Required: ...
# 4               Section 16.16.020 (B) - The provisions of this...
# 5               Section 16.24.340 (U) (2) – Boarding of Vacant...
# 6               Section 16.24.340 (U) (1) – Boarding of Vacant...
# 7               Section 12.08.210 - Abandoned Vehicles: Abando...
# 8               Section 17.40.580 - Certificate of Compliance:...
# 9               Section 16.24.130 – Certificate of Occupancy R...
# 10              Section 17.16.330 (B) (2)(3) - Domestic Animal...
# 11              Section 17.16.030 ((B) 4) - Consignment Sale (...
# 12              Section 16.24.030 & 17.04.060 - Overcrowding: ...
# 13              Section 17.04.060 (2) - Family: No more than e...
# 14              Section 10.20.130 - Dumping permitted in desig...
# 16              Section 10.20.330 – Dumpsters – Hours of Colle...
# 17              Section 16.24.490 (C) - Electrical System Haza...
# 18              Section 16.24.490 (C) - Electrical System Haza...
# 19              Section 16.24.500 (B) Receptacles: Every habit...
# 20              Section 16.24.500 (A) - Electrical Equipment I...
# 21              Section 16.24.500 (C) - Lighting Fixtures: Eve...
# 22              Section 16.24.490(A) - Electrical Facilities R...
# 23              Section 16.24.490 (B) - Electrical Service: Se...
# 24              Section 16.24.330 (K)(3) – Motor Vehicles (Par...
# 25              Section 16.24.330 (H) – Accessory Structures: ...
# 26              Section 16.24.340 (R) – Basement Hatchways: Ba...
# 27              Section 16.24.340 (J) – Balconies: Every exter...
# 28              Section 16.24.340 (K) – Chimneys and towers: A...
# 29              Section 16.24.340 (J) – Decks: Every exterior ...
# 30              Section 16.24.340 (H) – Decorative Features: A...
# ...                                                           ...
# 888             Special Events held on public property can onl...
# 889             All applicants for beer permits must supply th...
# 890             No permittee nor any of his/her agents shall d...
# 891             In disciplinary proceedings, it shall be no de...
# 892             When applying for an on or off-sale permit, al...
# 893             All applicants for a permit of any kind relati...
# 894             When ascertaining the age of a person purchasi...
# 896             When applying for a special event permit, appl...
# 903             All application fees for beer permits and beer...
# 904             The Metropolitan Beer Permit Board recognizes ...
# 906             Upon making application for a beer permit from...
# 907             Upon making application for an on-sale beer pe...
# 909             Permittees shall surrender their permits, in p...
# 910             All complaints requested to be heard by the Me...
# 911             An old location is any location that has had a...
# 912                                                       Rule 26
# 915             A permit holder may not avoid a hearing or pro...
# 916             Temporary permits shall not be issued by the E...
# 918             1. The grandfather clause of Ordinance 092-246...
# 921             No permittee shall expand the premises for whi...
# 922             Pursuant to Metropolitan Code of Laws Section ...
# 923             The following constitutes standard penalties f...
# 925             The beer board shall consider a permit holder'...
# 926             For all purposes under the metropolitan beer l...
# 927             The Beer Permit Board shall not entertain moti...
# 928             Applicants for special event permits will be l...
# 929             Upon suspension of a beer permit, the permitte...
# 930             If an application has not been granted or deni...
# 932             A permit shall not be issued by the Executive ...
# 933             This rule is applicable only to beer sales wit...
#
#                             remedial
# Original_Index
# 0                       CAAZ_BANNERS
# 1                   CAAH_BG_MATOWNER
# 2                    CAAH_BLDG_MAINT
# 3                   CAAB_BLDG_PERMIT
# 4                    CAAH_BLDG_SCOPE
# 5                 CAAH_BOARDING_REQU
# 6               CAAH_BOARDING_VABLDG
# 7                    CAMCL_SEW_CONCT
# 8                     CAAZ_CERT_COMP
# 9                      CAAH_CERT_OCC
# 10                CAAZ_CHICK_ANIMALS
# 11                 CAAZ_CONSIGN_SALE
# 12                  CAAZ_OVCROWDEDFM
# 13                  CAAZ_OVCROWDEDGH
# 14
# 16                  CAMCL_LIT_NOTICE
# 17                  CAAE_ELECSYS_HAZ
# 18              CAAE_ELECSYS_HAZCERT
# 19                 CAAE_ELECEA_RECPT
# 20                      CAAE_ELEC_EQ
# 21                 CAAE_ELECEQ_LIGHT
# 22                      CAAE_ELECFAC
# 23                CAAE_ELECSVC_PANEL
# 24                     CAAH_EXT_PARK
# 25                      CAAH_EXT_ACC
# 26                    CAAH_EXT_BAHAT
# 27                    CAAH_EXT_BALCO
# 28                   CAAH_EXT_CHIMTW
# 29                     CAAH_EXT_DECK
# 30                     CAAH_EXT_DECF
# ...                              ...
# 888
# 889
# 890
# 891
# 892
# 893
# 894
# 896
# 903
# 904
# 906
# 907
# 909
# 910
# 911
# 912
# 915
# 916
# 918
# 921
# 922
# 923
# 925
# 926
# 927
# 928
# 929
# 930
# 932
# 933
#
# [809 rows x 4 columns]

# %%
def tokenize_column(column_values):
    return word_tokenize(column_values)
    
def tokenize_row(index, row):
    desc = row['desc']
    text = row['text']
    
    desc_tokenized, text_tokenized = [], []
    
    if desc:
        desc_tokenized = tokenize_column(desc)
        
    if text:
        text_tokenized = tokenize_column(text)

    return (index, desc_tokenized, text_tokenized)

# %%
tokenized_data = list()

for index, row in master_violations.iterrows():
    tokenized_row_data = tokenize_row(index, row)
    tokenized_data.append(tokenized_row_data)

# %%
tokenized_df = pd.DataFrame(tokenized_data, columns=['Original_Index', 'tokenized_desc', 'tokenized_text'])
tokenized_df.set_index('Original_Index', inplace=True)

tokenized_df.head()
# Out:
#                                       tokenized_desc  \
# Original_Index
# 0                                          [Banners]
# 1               [Proper, Maintenance, Req, -, Owner]
# 2                         [Proper, Maintenance, Req]
# 3                       [Building, Permit, Required]
# 4                        [Scope, of, Building, Code]
#
#                                                    tokenized_text
# Original_Index
# 0               [Section, 17.32.060, &, 17.32.070, -, Banners,...
# 1               [Section, 16.16.030, (, B, ), -, Proper, maint...
# 2               [Section, 16.16.030, (, A, ), -, Proper, maint...
# 3               [Section, 16.28.010, -, Building, Permit, Requ...
# 4               [Section, 16.16.020, (, B, ), -, The, provisio...

# %%
master_violations = master_violations.join(tokenized_df)
master_violations.head()
# Out:
#                       type                            desc  \
# Original_Index
# 0                  BANNERS                         Banners
# 1               BGMATOWNER  Proper Maintenance Req - Owner
# 2                BLDGMAINT          Proper Maintenance Req
# 3               BLDGPERMIT        Building Permit Required
# 4                BLDGSCOPE          Scope of Building Code
#
#                                                              text  \
# Original_Index
# 0               Section 17.32.060 & 17.32.070 -  Banners: Bann...
# 1               Section 16.16.030 (B) - Proper maintenance req...
# 2               Section 16.16.030 (A) - Proper maintenance req...
# 3               Section 16.28.010 - Building Permit Required: ...
# 4               Section 16.16.020 (B) - The provisions of this...
#
#                         remedial                        tokenized_desc  \
# Original_Index
# 0                   CAAZ_BANNERS                             [Banners]
# 1               CAAH_BG_MATOWNER  [Proper, Maintenance, Req, -, Owner]
# 2                CAAH_BLDG_MAINT            [Proper, Maintenance, Req]
# 3               CAAB_BLDG_PERMIT          [Building, Permit, Required]
# 4                CAAH_BLDG_SCOPE           [Scope, of, Building, Code]
#
#                                                    tokenized_text
# Original_Index
# 0               [Section, 17.32.060, &, 17.32.070, -, Banners,...
# 1               [Section, 16.16.030, (, B, ), -, Proper, maint...
# 2               [Section, 16.16.030, (, A, ), -, Proper, maint...
# 3               [Section, 16.28.010, -, Building, Permit, Requ...
# 4               [Section, 16.16.020, (, B, ), -, The, provisio...
