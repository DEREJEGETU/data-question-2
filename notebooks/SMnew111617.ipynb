# %%
import pandas as pd 
import matplotlib as mpl 
import numpy as np 
import matplotlib.pyplot as plt 
import nltk
#nltk.download()
from nltk.tokenize import word_tokenize
from collections import Counter
from nltk.corpus import stopwords

# %%
##uploading the excel file
codes_violations = pd.read_excel("First_editversion_codesviolations.xlsx")

# %%
codes_violations
# Out:
#                                           VIOLATION_ID            ORG_ID  \
# 0                                                    1                 1
# 1                                                    2                 1
# 2                                                    4                 1
# 3                                                    5                 1
# 4                                                    6                 1
# 5                                                    7                 1
# 6                                                    8                 1
# 7                                                    9                 1
# 8                                                   10                 1
# 9                                                   11                 1
# 10                                                  12                 1
# 11                                                  13                 1
# 12                                                  14                 1
# 13                                                  15                 1
# 14                                                  16                 1
# 15   (B). It is unlawful for any person to dispose ...  CAMCL_DUMP_DESIG
# 16                                                  17                 1
# 17                                                  18                 1
# 18                                                  19                 1
# 19                                                  20                 1
# 20                                                  21                 1
# 21                                                  22                 1
# 22                                                  23                 1
# 23                                                  24                 1
# 24                                                  25                 1
# 25                                                  26                 1
# 26                                                  27                 1
# 27                                                  28                 1
# 28                                                  29                 1
# 29                                                  30                 1
# ..                                                 ...               ...
# 904                                                949                 1
# 905  Premeditated murder, all sex related crimes, s...               NaN
# 906                                                950                 1
# 907                                                951                 1
# 908  Failure to provide documents verifying Fire Ma...               NaN
# 909                                                952                 1
# 910                                                953                 1
# 911                                                954                 1
# 912                                                955                 1
# 913  All applications for beer permits must be file...               NaN
# 914  This amended rule supersedes and replaces the ...               NaN
# 915                                                956                 1
# 916                                                957                 1
# 917  However, in the event of a complete change in ...               NaN
# 918                                                959                 1
# 919  Any business grandfathered under either of the...               NaN
# 920  2. The distance requirements do not apply to a...               NaN
# 921                                                960                 1
# 922                                                961                 1
# 923                                                962                 1
# 924  These provisions shall apply unless the permit...               NaN
# 925                                                963                 1
# 926                                                964                 1
# 927                                                965                 1
# 928                                                966                 1
# 929                                                967                 1
# 930                                                968                 1
# 931  A grant and delay will be valid for 90 days.  ...               NaN
# 932                                                969                 1
# 933                                                970                 1
#
#     VIOLATION_TYPE                            VIOLATION_DESC  \
# 0          BANNERS                                   Banners
# 1       BGMATOWNER            Proper Maintenance Req - Owner
# 2        BLDGMAINT                    Proper Maintenance Req
# 3       BLDGPERMIT                  Building Permit Required
# 4        BLDGSCOPE                    Scope of Building Code
# 5       BOARDINGRQ                     Boarding Requirements
# 6         BOARDVAC              Boarding of Vacant Buildings
# 7           CARROW               Vehicle In The Right-Of-Way
# 8         CERTCOMP        Certificate of Compliance Required
# 9          CERTOCC         Certificate of Occupancy Required
# 10       CHICKFARM  Chickens and Other Domestic Farm Animals
# 11      CONSIGSALE                          Consignment Sale
# 12       CROWDEDFM           Overcrowding – Unrelated Adults
# 13         CROWDGH                 Overcrowding – Group Home
# 14       DUMPDESIG               Dumping in permitted places
# 15             NaN                                         N
# 16        DUMPSTER   Hours of Collection & Dumpster Required
# 17         ECSYSHZ                 Electrical System Hazards
# 18      ECSYSHZCRT           Electrical System Certification
# 19       ELECEAREC                    Electrical Receptacles
# 20          ELECEQ                     Electrical Equipment
# 21      ELECEQLIGH              Electrical Lighting Fixtures
# 22         ELECFAC            Electrical Facilities Required
# 23      ELECSVCPAN                  Electrical Service Panel
# 24          EXPARK   Exterior Prop Area – Vehicles – Parking
# 25          EXTACC     Exterior Prop Area – Acces Structures
# 26        EXTBAHAT    Exterior of Bldgs – Basement Hatchways
# 27          EXTBAL         Exterior of Buildings - Balconies
# 28       EXTCHIMTW   Exterior of Bldgs – Chimneys and Towers
# 29          EXTDEC             Exterior of Buildings – Decks
# ..             ...                                       ...
# 904          BBR17                 Crimes of moral turpitude
# 905            NaN                                         N
# 906          BBR18                         Health Department
# 907          BBR19                              Fire Marshal
# 908            NaN                                         N
# 909          BBR21                         Surrender permits
# 910          BBR22               Complaints filed in writing
# 911          BBR24                       Old or New Location
# 912          BBR26                Applications 10 days prior
# 913            NaN                                       NaN
# 914            NaN                                         N
# 915          BBR28       Cannot surrender to avoid penalties
# 916          BBR29  Cannot temporary permits with complaints
# 917            NaN                                         N
# 918          BBR30                             Grandfathered
# 919            NaN                                       NaN
# 920            NaN                                         N
# 921          BBR31                         Expanded premises
# 922          BBR32                           Caterer Permits
# 923          BBR34                        Standard penalties
# 924            NaN                                         N
# 925          BBR33                Past violations considered
# 926          BBR35                    LLC equals corporation
# 927          BBR36            No motions for reconsideration
# 928          BBR37                     Special Event Permits
# 929          BBR38                          Suspension Rules
# 930          BBR40                Deny permit after 6 months
# 931            NaN                                         N
# 932          BBR41          No permit issued with complaints
# 933          BBR39               Sports Authority Facilities
#
#                                         VIOLATION_TEXT         REMEDIAL_TEXT  \
# 0    Section 17.32.060 & 17.32.070 -  Banners: Bann...          CAAZ_BANNERS
# 1    Section 16.16.030 (B) - Proper maintenance req...      CAAH_BG_MATOWNER
# 2    Section 16.16.030 (A) - Proper maintenance req...       CAAH_BLDG_MAINT
# 3    Section 16.28.010 - Building Permit Required: ...      CAAB_BLDG_PERMIT
# 4    Section 16.16.020 (B) - The provisions of this...       CAAH_BLDG_SCOPE
# 5    Section 16.24.340 (U) (2) – Boarding of Vacant...    CAAH_BOARDING_REQU
# 6    Section 16.24.340 (U) (1) – Boarding of Vacant...  CAAH_BOARDING_VABLDG
# 7    Section 12.08.210 - Abandoned Vehicles: Abando...       CAMCL_SEW_CONCT
# 8    Section 17.40.580 - Certificate of Compliance:...        CAAZ_CERT_COMP
# 9    Section 16.24.130 – Certificate of Occupancy R...         CAAH_CERT_OCC
# 10   Section 17.16.330 (B) (2)(3) - Domestic Animal...    CAAZ_CHICK_ANIMALS
# 11   Section 17.16.030 ((B) 4) - Consignment Sale (...     CAAZ_CONSIGN_SALE
# 12   Section 16.24.030 & 17.04.060 - Overcrowding: ...      CAAZ_OVCROWDEDFM
# 13   Section 17.04.060 (2) - Family: No more than e...      CAAZ_OVCROWDEDGH
# 14   Section 10.20.130 - Dumping permitted in desig...                   NaN
# 15                                                 NaN                     1
# 16   Section 10.20.330 – Dumpsters – Hours of Colle...      CAMCL_LIT_NOTICE
# 17   Section 16.24.490 (C) - Electrical System Haza...      CAAE_ELECSYS_HAZ
# 18   Section 16.24.490 (C) - Electrical System Haza...  CAAE_ELECSYS_HAZCERT
# 19   Section 16.24.500 (B) Receptacles: Every habit...     CAAE_ELECEA_RECPT
# 20   Section 16.24.500 (A) - Electrical Equipment I...          CAAE_ELEC_EQ
# 21   Section 16.24.500 (C) - Lighting Fixtures: Eve...     CAAE_ELECEQ_LIGHT
# 22   Section 16.24.490(A) - Electrical Facilities R...          CAAE_ELECFAC
# 23   Section 16.24.490 (B) - Electrical Service: Se...    CAAE_ELECSVC_PANEL
# 24   Section 16.24.330 (K)(3) – Motor Vehicles (Par...         CAAH_EXT_PARK
# 25   Section 16.24.330 (H) – Accessory Structures: ...          CAAH_EXT_ACC
# 26   Section 16.24.340 (R) – Basement Hatchways: Ba...        CAAH_EXT_BAHAT
# 27   Section 16.24.340 (J) – Balconies: Every exter...        CAAH_EXT_BALCO
# 28   Section 16.24.340 (K) – Chimneys and towers: A...       CAAH_EXT_CHIMTW
# 29   Section 16.24.340 (J) – Decks: Every exterior ...         CAAH_EXT_DECK
# ..                                                 ...                   ...
# 904  The Metropolitan Beer Permit Board recognizes ...                   NaN
# 905                                                NaN                 10635
# 906  Upon making application for a beer permit from...                   NaN
# 907  Upon making application for an on-sale beer pe...                   NaN
# 908                                                NaN                 10635
# 909  Permittees shall surrender their permits, in p...                   NaN
# 910  All complaints requested to be heard by the Me...                   NaN
# 911  An old location is any location that has had a...                   NaN
# 912                                            Rule 26                   NaN
# 913                                                NaN                   NaN
# 914                                                NaN                 10635
# 915  A permit holder may not avoid a hearing or pro...                   NaN
# 916  Temporary permits shall not be issued by the E...                   NaN
# 917                                                NaN                 10635
# 918  1. The grandfather clause of Ordinance 092-246...                   NaN
# 919                                                NaN                   NaN
# 920                                                NaN                 10635
# 921  No permittee shall expand the premises for whi...                   NaN
# 922  Pursuant to Metropolitan Code of Laws Section ...                   NaN
# 923  The following constitutes standard penalties f...                   NaN
# 924                                                NaN                 10635
# 925  The beer board shall consider a permit holder'...                   NaN
# 926  For all purposes under the metropolitan beer l...                   NaN
# 927  The Beer Permit Board shall not entertain moti...                   NaN
# 928  Applicants for special event permits will be l...                   NaN
# 929  Upon suspension of a beer permit, the permitte...                   NaN
# 930  If an application has not been granted or deni...                   NaN
# 931                                                NaN                 10635
# 932  A permit shall not be issued by the Executive ...                   NaN
# 933  This rule is applicable only to beer sales wit...                   NaN
#
#                  TABLE_NAME EXPIRED_FLAG                DATE_EXPIRED  \
# 0                       NaT            N                         NaN
# 1                       NaT            N                         NaN
# 2                       NaT            N                         NaN
# 3                       NaT            N                         NaN
# 4                       NaT            N                         NaN
# 5                       NaT            N                         NaN
# 6                       NaT            N                         NaN
# 7                       NaT            N                         NaN
# 8                       NaT            N                         NaN
# 9                       NaT            N                         NaN
# 10                      NaT            N                         NaN
# 11                      NaT            N                         NaN
# 12                      NaT            N                         NaN
# 13                      NaT            N                         NaN
# 14                      NaT          NaN                         NaN
# 15  2014-07-09 08:03:52.640          NaN                         NaN
# 16                      NaT            N                         NaN
# 17                      NaT            N                         NaN
# 18                      NaT            N                         NaN
# 19                      NaT            N                         NaN
# 20                      NaT            N                         NaN
# 21                      NaT            N                         NaN
# 22                      NaT            N                         NaN
# 23                      NaT            N                         NaN
# 24                      NaT            N                         NaN
# 25                      NaT            N                         NaN
# 26                      NaT            N                         NaN
# 27                      NaT            N                         NaN
# 28                      NaT            N                         NaN
# 29                      NaT            N                         NaN
# ..                      ...          ...                         ...
# 904                     NaT          NaN                         NaN
# 905 2017-05-19 13:02:29.590          NaN                         NaN
# 906                     NaT            N                         NaN
# 907                     NaT          NaN                         NaN
# 908 2017-05-19 13:04:10.247          NaN                         NaN
# 909                     NaT            N                         NaN
# 910                     NaT            N                         NaN
# 911                     NaT            N                         NaN
# 912                     NaT          NaN                         NaN
# 913                     NaT          NaN                         NaN
# 914 2017-05-19 13:28:13.063          NaN                         NaN
# 915                     NaT            N                         NaN
# 916                     NaT          NaN                         NaN
# 917 2017-05-19 13:30:56.267          NaN                         NaN
# 918                     NaT          NaN                         NaN
# 919                     NaT          NaN                         NaN
# 920 2017-05-19 13:37:16.470          NaN                         NaN
# 921                     NaT            N                         NaN
# 922                     NaT            N                         NaN
# 923                     NaT          NaN                         NaN
# 924 2017-05-19 13:59:10.973        10635  2017-05-19 14:02:49.207000
# 925                     NaT            N                         NaN
# 926                     NaT            N                         NaN
# 927                     NaT            N                         NaN
# 928                     NaT            N                         NaN
# 929                     NaT            N                         NaN
# 930                     NaT          NaN                         NaN
# 931 2017-05-19 14:12:16.410          NaN                         NaN
# 932                     NaT            N                         NaN
# 933                     NaT            N                         NaN
#
#      CREATED_BY                DATE_CREATED MODIFIED_BY DATE_MODIFIED  \
# 0           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 1           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 2           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 3           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 4           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 5           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 6           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 7           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 8           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 9           1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 10          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 11          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 12          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 13          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 14          NaN                         NaN         NaN           NaT
# 15          NaN                         NaN         NaN           NaT
# 16          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 17          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 18          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 19          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 20          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 21          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 22          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 23          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 24          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 25          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 26          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 27          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 28          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# 29          1.0  2014-07-09 08:03:52.640000         NaN           NaT
# ..          ...                         ...         ...           ...
# 904         NaN                         NaN         NaN           NaT
# 905         NaN                         NaN         NaN           NaT
# 906     10635.0  2017-05-19 13:03:29.120000         NaN           NaT
# 907         NaN                         NaN         NaN           NaT
# 908         NaN                         NaN         NaN           NaT
# 909     10635.0  2017-05-19 13:04:56.403000         NaN           NaT
# 910     10635.0  2017-05-19 13:05:39.793000         NaN           NaT
# 911     10635.0  2017-05-19 13:06:28.623000         NaN           NaT
# 912         NaN                         NaN         NaN           NaT
# 913         NaN                         NaN         NaN           NaT
# 914         NaN                         NaN         NaN           NaT
# 915     10635.0  2017-05-19 13:29:30.797000         NaN           NaT
# 916         NaN                         NaN         NaN           NaT
# 917         NaN                         NaN         NaN           NaT
# 918         NaN                         NaN         NaN           NaT
# 919         NaN                         NaN         NaN           NaT
# 920         NaN                         NaN         NaN           NaT
# 921     10635.0  2017-05-19 13:38:33.533000         NaN           NaT
# 922     10635.0  2017-05-19 13:56:24.863000         NaN           NaT
# 923         NaN                         NaN         NaN           NaT
# 924         NaN                         NaN         NaN           NaT
# 925     10635.0  2017-05-19 13:59:48.627000         NaN           NaT
# 926     10635.0  2017-05-19 14:03:34.833000         NaN           NaT
# 927     10635.0  2017-05-19 14:04:56.020000         NaN           NaT
# 928     10635.0  2017-05-19 14:08:59.410000         NaN           NaT
# 929     10635.0  2017-05-19 14:10:16.943000         NaN           NaT
# 930         NaN                         NaN         NaN           NaT
# 931         NaN                         NaN         NaN           NaT
# 932     10635.0  2017-05-19 14:12:53.083000         NaN           NaT
# 933     10635.0  2017-05-19 14:16:46.803000         NaN           NaT
#
#      FEE_SETUP_ID  Unnamed: 14
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# 5             NaN          NaN
# 6             NaN          NaN
# 7             NaN          NaN
# 8             NaN          NaN
# 9             NaN          NaN
# 10            NaN          NaN
# 11            NaN          NaN
# 12            NaN          NaN
# 13            NaN          NaN
# 14            NaN          NaN
# 15            NaN          NaN
# 16            NaN          NaN
# 17            NaN          NaN
# 18            NaN          NaN
# 19            NaN          NaN
# 20            NaN          NaN
# 21            NaN          NaN
# 22            NaN          NaN
# 23            NaN          NaN
# 24            NaN          NaN
# 25            NaN          NaN
# 26            NaN          NaN
# 27            NaN          NaN
# 28            NaN          NaN
# 29            NaN          NaN
# ..            ...          ...
# 904           NaN          NaN
# 905           NaN          NaN
# 906           NaN          NaN
# 907           NaN          NaN
# 908           NaN          NaN
# 909           NaN          NaN
# 910           NaN          NaN
# 911           NaN          NaN
# 912           NaN          NaN
# 913           NaN          NaN
# 914           NaN          NaN
# 915           NaN          NaN
# 916           NaN          NaN
# 917           NaN          NaN
# 918           NaN          NaN
# 919           NaN          NaN
# 920           NaN          NaN
# 921           NaN          NaN
# 922           NaN          NaN
# 923           NaN          NaN
# 924           NaN          NaN
# 925           NaN          NaN
# 926           NaN          NaN
# 927           NaN          NaN
# 928           NaN          NaN
# 929           NaN          NaN
# 930           NaN          NaN
# 931           NaN          NaN
# 932           NaN          NaN
# 933           NaN          NaN
#
# [934 rows x 15 columns]

# %%
#Finding the info for the file
codes_violations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 15 columns):
# VIOLATION_ID      928 non-null object
# ORG_ID            789 non-null object
# VIOLATION_TYPE    788 non-null object
# VIOLATION_DESC    925 non-null object
# VIOLATION_TEXT    695 non-null object
# REMEDIAL_TEXT     345 non-null object
# TABLE_NAME        137 non-null datetime64[ns]
# EXPIRED_FLAG      651 non-null object
# DATE_EXPIRED      2 non-null object
# CREATED_BY        650 non-null float64
# DATE_CREATED      651 non-null object
# MODIFIED_BY       23 non-null object
# DATE_MODIFIED     22 non-null datetime64[ns]
# FEE_SETUP_ID      0 non-null float64
# Unnamed: 14       0 non-null float64
# dtypes: datetime64[ns](2), float64(3), object(10)
# memory usage: 109.5+ KB

# %%
# to find the unique entries in the column
codes_violations.ORG_ID.unique()
# Out:
# array([1, 'CAMCL_DUMP_DESIG', nan], dtype=object)

# %%
codes_violations.VIOLATION_DESC.unique()
# Out:
# array(['Banners', 'Proper Maintenance Req - Owner',
#        'Proper Maintenance Req', 'Building Permit Required',
#        'Scope of Building Code', 'Boarding Requirements',
#        'Boarding of Vacant Buildings', 'Vehicle In The Right-Of-Way',
#        'Certificate of Compliance Required',
#        'Certificate of Occupancy Required',
#        'Chickens and Other Domestic Farm Animals', 'Consignment Sale',
#        'Overcrowding – Unrelated Adults', 'Overcrowding – Group Home',
#        'Dumping in permitted places', 'N',
#        'Hours of Collection & Dumpster Required',
#        'Electrical System Hazards', 'Electrical System Certification',
#        'Electrical Receptacles', 'Electrical Equipment ',
#        'Electrical Lighting Fixtures', 'Electrical Facilities Required',
#        'Electrical Service Panel',
#        'Exterior Prop Area – Vehicles – Parking',
#        'Exterior Prop Area – Acces Structures',
#        'Exterior of Bldgs – Basement Hatchways',
#        'Exterior of Buildings - Balconies',
#        'Exterior of Bldgs – Chimneys and Towers',
#        'Exterior of Buildings – Decks',
#        'Exterior of Bldgs – Decorative Features',
#        'Exterior Prop Area – Fences  Barbed Wire',
#        'Exterior of Buildings – Doors',
#        'Exterior of Buildings – Premises ID Res',
#        'Extermination – Multiple Occupancy',
#        'Extermination – Single Occupant', 'Extermination – Owner',
#        'Extermination Required', 'Extermination – Occupant',
#        'Exterior Prop Area – Exhaust Vents',
#        'Exterior of Buildings – Exterior Walls',
#        'Exterior of Buildings – Foundation Walls',
#        'Exterior Prop Area – Fence Material Main',
#        'Exterior Prop Area – Fencing Materials',
#        'Exterior Prop Area – Gates',
#        'Exterior of Bldgs – Guards Basement Wind',
#        'Exterior of Buildings – Glazing',
#        'Exterior Prop Area – Grading Required',
#        'Exterior of Bldgs – Roofs– Gutter Sys',
#        'Exterior of Bldgs – Handrails and Guards',
#        'Exterior of Buildings – Openable Windows',
#        'Exterior of Bldgs – Overhang Extensions',
#        'Exterior of Bldgs – Premises ID Nonres',
#        'Exterior of Bldg – Premises ID Multi-Fam',
#        'Exterior of Buildings - Porches',
#        'Exterior Prop Area – Designated Parking',
#        'Exterior of Bldgs – Treatment Metal Sur',
#        'Exterior of Bldgs – Treatment (Siding)',
#        'Exterior of Bldgs – Pro Treatment (Wood)',
#        'Exterior Repair – General',
#        'Exterior Prop Area – Rodent Harborage',
#        'Exterior of bldgs – Roofs– Drainage Sys',
#        'Exterior of Bldgs – Roofs – Roof System',
#        'Exterior Prop Area – Sanitation',
#        'Exterior of Bldgs  Insect Screens Nonres',
#        'Exterior of Bldgs – Insect Screens Res',
#        'Exterior Prop Area – Sidewalks',
#        'Exterior of Buildings – Stairways',
#        'Exterior of Bldgs – Structural Members',
#        'Exterior Prop Area – Swimming Pools',
#        'Exterior Prop Area – Trailers Watercraft',
#        'Exterior Prop Area – Veh – Inop/Unlc',
#        'Exterior Prop Area – Vehicle Painting',
#        'Exterior Prop Area – Veh – Dis/Repair',
#        'Exterior Prop Area – High Weeds',
#        'Ext of Bldgs – Wind, Skylit Door Frames',
#        'Fence Height – Off Right-Of-Way (opaque)',
#        'Fence Height – Inside Front Setback',
#        'Fence Height – Side and Rear Setback',
#        'Fence Height – Off Right-Of-Way (open)',
#        'Fire Safety – Emergency Escape (Doors)',
#        'Fire Protection – Smoke Detector Install',
#        'Fire Safety – Emergency Escape',
#        'Fire Safety Requirements – Egress',
#        'Fire Safety – Emergency Escape (Opening)',
#        'Fire Safety – Emergency Escape (Height)',
#        'Fire Safety – Emergency Escape (Width)',
#        'Fire Safety – Emergency Escape (Op)',
#        'Fire Protection – Smoke Detectors', 'Garage Sales',
#        'Exterior of Buildings – Graffiti',
#        'Hazardous, pathogenic, radioactive waste',
#        'Heating – Heating Facilities Required',
#        'Heating – Residential Occupancies', 'Heating – Heat Supply',
#        'Heat – Occupiable Work Spaces',
#        'Home Occupation – Permit Required', 'Home Occupation – Conditions',
#        'Sanitation requirements', 'Vacation of buildings',
#        'Interiors of Bldgs and Structures Gen',
#        'Interior of Buildings - Surfaces',
#        'Interior of Bldgs – Handrails and Guards',
#        'Interior of Buildings – Interior Doors',
#        'Interior of Bldgs – Stairs Walking Surf',
#        'Landlord Registration Required',
#        'Light – Common Halls and Stairways', 'Lighting (Emission)',
#        'Light – Habitable Spaces', 'Lighting (MAX Level)',
#        'Light – Other Spaces', 'Litter on public places - citizens',
#        'Litter on business premises -owner',
#        'Handbills - distribution in public',
#        'Handbills - distribution on vehicles',
#        'Posting notices prohibited', 'Proper placement in receptacles ',
#        'Litter on private property - owners',
#        'Litter on occupied private property', 'Litter on vacant lots',
#        'Litter from vehicles', 'Litter from vehicle loads tires',
#        'Litter in water', 'Mechanical Equip – Remove of Combus Prod',
#        'Mechanical Equip – Appliances', 'Mobile Vending',
#        'Continuous & Intermittent Noise', 'Garbage causing nuisance',
#        'Occupancy – Access from Bedrooms',
#        'Occupancy – Bedroom Requirements', 'Occupancy Limits – Privacy',
#        'Occupancy – Overcrowding', 'Occupancy – Other Requirements',
#        'Occupancy Prohibited', 'Occupancy – Minimum Ceiling Heights',
#        'Occupancy – Minimum Room Widths', 'Occupancy – Sleeping Rooms',
#        'Occupancy – Water Closet Access',
#        'Exterior Prop Area – Open Storage - All',
#        'Exterior Prop Area – Open Stor – Debris',
#        'Exterior Prop Area – Open Storage – JTD',
#        'Exterior Prop Area – Open Storage - Veh',
#        'Paving Permanent Parking Areas',
#        'Building and Zoning Permit Required', 'Plumbing – Dwelling Units',
#        'Plumbing – Employee Facilities',
#        'Plumbing Systems – Fixture Clearance',
#        'Plumbing Systems – General Requirements', 'Plumbing – Hotel',
#        'Plumbing – Rooming Houses', 'Plumbing Systems – System Hazards',
#        'Nuisance declared - holes',
#        'Failure to Maintain Bldgs or Structures', 'Security Residence',
#        'Accumulation of garbage', 'Storage and disposal of garbage',
#        'Rubbish and Garbage – Disposal  Garbage',
#        'Rubbish and Garbage – Containers',
#        'Rubbish and Garbage – Disposal Rubbish',
#        'Rubbish and Garbage – Garbage Facilities',
#        'Rubbish and Garbage – Rubbish Storage',
#        'Sanitary Drainage System – Maintenance',
#        'Sanitary Drainage System – General', 'School Buses',
#        'Connect to public sewer', 'Private connections permitted',
#        'Runoff in body of water', 'Runoff of contents unlawful',
#        'Septic Tank - Sewage on ground', 'Prohibited Sign - Portable Sign',
#        'Prohibited Signs - Blank', 'Signs – Greater than 25 Percent',
#        'Abandoned Signs', 'Dilapidated Signs', 'Prohibited Sign - Harmful',
#        'Signs – Prohibited Placement –BUS',
#        'Signs – Prohibited Placement – Public', 'Sign Maintenance ',
#        'Sign Material', 'Electronic Sign (LED) Display Motion',
#        'Sign Permit Required', 'Prohibited Signs',
#        'Signs – Prohibited – Handheld',
#        'Electronic Sign (LED) Display Timing', 'Unsafe or Illegal Sign',
#        'Signs – Prohibited (Vehicle Signs)', 'Signs – Prohibited - Wind',
#        'Interior of Bldgs – Structural Members', 'Stop Work Order Posted',
#        'Temporary U&O Expired', 'Toilet Rooms – Location',
#        'Toilet Rooms – Privacy',
#        'Toilet Rooms – Employee Toilet Facilitie',
#        'Tractor-Trailer Parking', 'Trash Cans', 'Commercial Truck Parking',
#        'Use Not Permitted', 'Vacant Buildings',
#        'Ventilation – Bathrooms and Toilet Rooms',
#        'Ventilation – Cooking Facilities',
#        'Ventilation – Clothes Dryer Exhaust ',
#        'Ventilation – Habitable Spaces',
#        'Ventilation – Process Ventilation',
#        'Water System – Contamination ', 'Water System – General',
#        'Water – Supply', 'Water – Water Heating Facilities',
#        'Violations - Post Construction Treatment',
#        'Violations for Water Quality Impacts',
#        'Environmental Court Proceedings',
#        'Violations - for Construction Activities', 'HOUSE DISREPAIR',
#        'ACCESSORY STRUCTURES', 'BOAT STORAGE IN FRONT YARD PROHIBITED',
#        'HOURS OF COLLECTION & DUMPSTER REQUIRE', 'EXHAUST FAN DISCHARGE',
#        'EXTERIOR REPAIR', 'FAILURE TO SECURE', 'FENCE MATERIAL',
#        'GATE MAINTENANCE', 'GRAFFITI', 'HIGH WEEDS',
#        'UNLIC / INOP / ACCUMULATION MTR VEHICLES', 'INTERIOR REPAIR',
#        'LANDLORD REGISTRATION', 'OPEN STORAGE, JUNK, TRASH, DEBRIS',
#        'PARKING ON GRASS', 'PARKING AREA EXCEEDS 25%',
#        'ADDRESS ID COMMERCIAL', 'ADDRESS ID MULTI FAMILY',
#        'ADDRESS ID RESIDENTIAL', 'RODENT INFESTATION',
#        'SIDEWALK AND DRIVEWAY MAINT', 'SWIMMING POOLS', 'TRASH CANS',
#        'BUILDING PERMIT REQUIRED', 'STOP WORK ORDER POSTED',
#        'TEMPORARY U&O EXPIRED', 'ELECTRICAL EQUIPMENT',
#        'ELECTRICAL RECEPTACLES', 'ELECTRICAL LIGHTING FIXTURES',
#        'ELECTRICAL FACILITIES REQUIRED', 'ELECTRICAL SERVICE PANEL',
#        'ELECTRICAL SYSTEM HAZARDS', 'ELECTRICAL SYSTEM CERTIFICATION',
#        'FIRE PROTECTION – SMOKE DETECTOR INSTALL',
#        'FIRE PROTECTION – SMOKE DETECTORS',
#        'FIRE SAFETY – EMERGENCY ESCAPE (DOORS)',
#        'FIRE SAFETY – EMERGENCY ESCAPE',
#        'FIRE SAFETY REQUIREMENTS – EGRESS',
#        'FIRE SAFETY – EMERGENCY ESCAPE (OPENING)',
#        'FIRE SAFETY – EMERGENCY ESCAPE (HEIGHT)',
#        'FIRE SAFETY – EMERGENCY ESCAPE (WIDTH)',
#        'FIRE SAFETY – EMERGENCY ESCAPE (OP)',
#        'PROPER MAINTENANCE REQ - OWNER', 'PROPER MAINTENANCE REQ',
#        'SCOPE OF BUILDING CODE', 'BOARDING REQUIREMENTS',
#        'BOARDING OF VACANT BUILDINGS', 'CERTIFICATE OF OCCUPANCY REQUIRED',
#        'EXTERIOR PROP AREA – FENCES  BARBED WIRE',
#        'EXTERIOR PROP AREA – ACCES STRUCTURES',
#        'EXTERIOR OF BLDGS – BASEMENT HATCHWAYS',
#        'EXTERIOR OF BUILDINGS - BALCONIES',
#        'EXTERIOR OF BLDGS – CHIMNEYS AND TOWERS',
#        'EXTERIOR OF BLDGS – DECORATIVE FEATURES',
#        'EXTERIOR OF BUILDINGS – DECKS', 'EXTERIOR OF BUILDINGS – DOORS',
#        'EXTERIOR PROP AREA – EXHAUST VENTS',
#        'EXTERIOR OF BUILDINGS – EXTERIOR WALLS',
#        'EXTERIOR OF BUILDINGS – FOUNDATION WALLS',
#        'EXTERIOR PROP AREA – FENCE MATERIAL MAIN',
#        'EXTERIOR PROP AREA – FENCING MATERIALS',
#        'EXTERIOR PROP AREA – GATES', 'EXTERIOR OF BUILDINGS – GLAZING',
#        'EXTERIOR PROP AREA – GRADING REQUIRED',
#        'EXTERIOR OF BLDGS – ROOFS– GUTTER SYS',
#        'EXTERIOR OF BLDGS – HANDRAILS AND GUARDS',
#        'EXTERIOR OF BLDGS  INSECT SCREENS NONRES',
#        'EXTERIOR OF BLDGS – INSECT SCREENS RES',
#        'EXTERIOR OF BUILDINGS – OPENABLE WINDOWS',
#        'EXTERIOR OF BLDGS – OVERHANG EXTENSIONS',
#        'EXTERIOR PROP AREA – VEHICLES – PARKING',
#        'EXTERIOR OF BLDGS – PREMISES ID NONRES',
#        'EXTERIOR OF BUILDINGS – PREMISES ID RES',
#        'EXTERIOR OF BLDG – PREMISES ID MULTI-FAM',
#        'EXTERIOR OF BUILDINGS - PORCHES',
#        'EXTERIOR PROP AREA – DESIGNATED PARKING',
#        'EXTERIOR OF BLDGS – TREATMENT METAL SUR',
#        'EXTERIOR OF BLDGS – TREATMENT (SIDING)',
#        'EXTERIOR OF BLDGS – PRO TREATMENT (WOOD)',
#        'EXTERIOR PROP AREA – RODENT HARBORAGE',
#        'EXTERIOR OF BLDGS – ROOFS– DRAINAGE SYS',
#        'EXTERIOR OF BLDGS – ROOFS – ROOF SYSTEM',
#        'EXTERIOR PROP AREA – SANITATION', 'EXTERIOR PROP AREA – SIDEWALKS',
#        'EXTERIOR OF BUILDINGS – STAIRWAYS',
#        'EXTERIOR OF BLDGS – STRUCTURAL MEMBERS',
#        'EXTERIOR PROP AREA – SWIMMING POOLS',
#        'EXTERIOR PROP AREA – TRAILERS WATERCRAFT',
#        'EXTERIOR PROP AREA – VEH – INOP/UNLC',
#        'EXTERIOR PROP AREA – VEHICLE PAINTING',
#        'EXTERIOR PROP AREA – VEH – DIS/REPAIR',
#        'EXTERIOR PROP AREA – HIGH WEEDS',
#        'EXT OF BLDGS – WIND, SKYLIT DOOR FRAMES',
#        'EXTERMINATION – MULTIPLE OCCUPANCY',
#        'EXTERMINATION – SINGLE OCCUPANT', 'EXTERMINATION – OWNER',
#        'EXTERMINATION REQUIRED', 'EXTERMINATION – OCCUPANT',
#        'EXTERIOR REPAIR – GENERAL',
#        'EXTERIOR OF BLDGS – GUARDS BASEMENT WIND',
#        'EXTERIOR OF BUILDINGS – GRAFFITI',
#        'HEATING – HEATING FACILITIES REQUIRED',
#        'HEATING – RESIDENTIAL OCCUPANCIES', 'HEATING – HEAT SUPPLY',
#        'HEAT – OCCUPIABLE WORK SPACES',
#        'INTERIORS OF BLDGS AND STRUCTURES GEN',
#        'INTERIOR OF BUILDINGS - SURFACES',
#        'INTERIOR OF BLDGS – HANDRAILS AND GUARDS',
#        'INTERIOR OF BUILDINGS – INTERIOR DOORS',
#        'INTERIOR OF BLDGS – STAIRS WALKING SURF',
#        'LIGHT – COMMON HALLS AND STAIRWAYS', 'LIGHT – HABITABLE SPACES',
#        'LIGHT – OTHER SPACES', 'OCCUPANCY – ACCESS FROM BEDROOMS',
#        'OCCUPANCY – BEDROOM REQUIREMENTS', 'OCCUPANCY LIMITS – PRIVACY',
#        'OCCUPANCY – OVERCROWDING', 'OCCUPANCY – OTHER REQUIREMENTS',
#        'OCCUPANCY PROHIBITED', 'OCCUPANCY – MINIMUM CEILING HEIGHTS',
#        'OCCUPANCY – MINIMUM ROOM WIDTHS', 'OCCUPANCY – SLEEPING ROOMS',
#        'OCCUPANCY – WATER CLOSET ACCESS',
#        'EXTERIOR PROP AREA – OPEN STORAGE - ALL',
#        'EXTERIOR PROP AREA – OPEN STOR – DEBRIS',
#        'EXTERIOR PROP AREA – OPEN STORAGE – JTD',
#        'EXTERIOR PROP AREA – OPEN STORAGE - VEH',
#        'FAILURE TO MAINTAIN BLDGS OR STRUCTURES',
#        'RUBBISH AND GARBAGE – DISPOSAL  GARBAGE',
#        'RUBBISH AND GARBAGE – CONTAINERS',
#        'RUBBISH AND GARBAGE – DISPOSAL RUBBISH',
#        'RUBBISH AND GARBAGE – GARBAGE FACILITIES',
#        'RUBBISH AND GARBAGE – RUBBISH STORAGE', 'SCHOOL BUSES',
#        'INTERIOR OF BLDGS – STRUCTURAL MEMBERS', 'TRACTOR-TRAILER PARKING',
#        'COMMERCIAL TRUCK PARKING', 'VACANT BUILDINGS',
#        'VENTILATION – BATHROOMS AND TOILET ROOMS',
#        'VENTILATION – COOKING FACILITIES',
#        'VENTILATION – CLOTHES DRYER EXHAUST',
#        'VENTILATION – HABITABLE SPACES',
#        'VENTILATION – PROCESS VENTILATION',
#        'MECHANICAL EQUIP – REMOVE OF COMBUS PROD',
#        'MECHANICAL EQUIP – APPLIANCES', 'PLUMBING – DWELLING UNITS',
#        'PLUMBING – EMPLOYEE FACILITIES',
#        'PLUMBING SYSTEMS – FIXTURE CLEARANCE',
#        'PLUMBING SYSTEMS – GENERAL REQUIREMENTS', 'PLUMBING – HOTEL',
#        'PLUMBING – ROOMING HOUSES', 'PLUMBING SYSTEMS – SYSTEM HAZARDS',
#        'SANITARY DRAINAGE SYSTEM – MAINTENANCE',
#        'SANITARY DRAINAGE SYSTEM – GENERAL', 'TOILET ROOMS – LOCATION',
#        'TOILET ROOMS – PRIVACY',
#        'TOILET ROOMS – EMPLOYEE TOILET FACILITIE',
#        'WATER SYSTEM – CONTAMINATION', 'WATER SYSTEM – GENERAL',
#        'WATER – SUPPLY', 'WATER – WATER HEATING FACILITIES',
#        'LANDLORD REGISTRATION REQUIRED', 'BANNERS',
#        'VEHICLE IN THE RIGHT OF WAY', 'CERTIFICATE OF COMPLIANCE REQUIRED',
#        'CERTIFICATE COMPLIANCE REQ',
#        'CHICKENS AND OTHER DOMESTIC FARM ANIMALS',
#        'COMMERCIAL VEHICLE RESIDENTIAL DISTRICT', 'CONSIGNMENT SALE',
#        'FENCE HEIGHT', 'FENCE HEIGHT – INSIDE FRONT SETBACK',
#        'FENCE HEIGHT – OFF RIGHT-OF-WAY (OPEN)',
#        'FENCE HEIGHT – OFF RIGHT-OF-WAY (OPAQUE)',
#        'FENCE HEIGHT – SIDE AND REAR SETBACK', 'GARAGE SALES',
#        'HOME OCCUPATION – CONDITIONS', 'HOME OCCUPATION – PERMIT REQUIRED',
#        'LIGHTING (EMISSION)', 'LIGHTING (MAX LEVEL)', 'MOBILE VENDING',
#        'CONTINUOUS & INTERMITTENT NOISE',
#        'OVERCROWDING – UNRELATED ADULTS', 'OVERCROWDING – GROUP HOME',
#        'OVERCROWDING', 'PAVING PERMANENT PARKING AREAS',
#        'BUILDING AND ZONING PERMIT REQUIRED',
#        'FAILURE TO OBTAIN REQUIRED USE PERMIT', 'SECURITY RESIDENCE',
#        'PROHIBITED SIGNS - BLANK', 'PROHIBITED SIGN - PORTABLE SIGN',
#        'SIGNS – GREATER THAN 25 PERCENT', 'ABANDONED SIGNS',
#        'DILAPIDATED SIGNS', 'SIGNS – PROHIBITED – HANDHELD',
#        'SIGNS – PROHIBITED PLACEMENT –BUS',
#        'SIGNS – PROHIBITED PLACEMENT – PUBLIC', 'SIGN MAINTENANCE',
#        'SIGN MATERIAL', 'ELECTRONIC SIGN (LED) DISPLAY MOTION',
#        'SIGN PERMIT REQUIRED', 'PROHIBITED ON POSTS AND POLES',
#        'PROHIBITED SIGNS', ' SIGNS IN ROW', 'ON-PREMISES TEMPORARY SIGNS',
#        'ELECTRONIC SIGN (LED) DISPLAY TIMING', 'UNSAFE OR ILLEGAL SIGN',
#        'SIGNS – PROHIBITED (VEHICLE SIGNS)', 'SIGNS  – PROHIBITED - WIND',
#        'WINDOW SIGNS AND DISPLAY', 'USE NOT PERMITTED',
#        'CERTIFICATE OF COMPLIANCE', 'MAINTAIN LANDSCAPE MATERIAL',
#        'TREE REMOVAL PERMIT', 'COMPLY WITH APPROVED PLANS',
#        'TREE PROTECTION', 'HAZARDOUS TREE REMOVAL', nan, 'REWIRE',
#        'RELOCATE ELECTRICAL SERVICE', 'CONDUIT AND WEATHERHEAD',
#        'BATHROOM/KITCHEN GFCI OUTLET',
#        'ELECTRICAL SYSTEM CHECKED AND CERTIFIED',
#        'REPAIR DEFECTIVE SERVICE PANEL',
#        'REPLACE, REPAIR DEFECTIVE EQUIP.',
#        'REPLACE MISSING WALL OUTLET COVER',
#        'REPLACE MISSING WALL SWITCH COVERS',
#        'REPLACE SUBSTANDARD WIRING (DROP-CORDS)',
#        'PROVIDE CONDUITS FOR EXPOSED WIRING', 'REMOVE EXTENSION CORDS',
#        'REPLACE CEILING LIGHT FIXTURE COVERS', 'PROVIDE JUNCTION BOX',
#        'EXTERIOR PORCH LIGHT', 'REPLACE MISSING FUSE BLANKS',
#        'REMOVE, REPLACE SUDSTANDARD WIRING', 'BATHROOM GFCI OUTLET',
#        'DEFECTIVE WALL OUTLETS ON EXTERIOR',
#        'CORRECT OTHER ELECTRICAL DEFECTS', 'DOG EXCREMENT',
#        'HAZARDOUS WASTE', 'GARBAGE CONTAINER LIDS', 'ILLEGAL DUMPING',
#        'LITTER ON PRIVATE PROPERTY', 'LITTER ON PUBLIC PROPERTY',
#        'LITTER FROM VEHICLES', 'EXCESS VEGETATION',
#        'GARBAGE APPROVED CONTAINERS', 'RAT HARBORAGE GARBAGE',
#        'JUNK TRASH RAT HARBORAGE', 'STAGNANT WATER',
#        'DIRT, FILTH, GARBAGE', 'DEFECTIVE ELECTRIC WALL BASE HEATER',
#        'MISSING HEAT CONTROL KNOBS', 'SEAL OPEN GRATE',
#        'DEFECTIVE HEAT SUPPLY VENTS IN BASEMENT',
#        'HEATING SYSTEM PROPERLY INSTALLED',
#        'ADEQUATE VENTILATION FOR BATHROOM', 'SMOKE DETECTORS',
#        'HVAC SYSTEM REPAIR', 'FORCED AIR DUCT REPAIR', 'KEEPING CHICKENS',
#        'RUNNING WATER REQUIRED 2', 'SEWAGE DISCHARGE STREAM',
#        'SEWER, CONNECT TO PUBLIC', 'SEWAGE ON GROUND',
#        'SEWAGE DISP. IMPROPERLY MAINT.', 'SEWAGE - ILLEGAL WASTE LINE',
#        'FAULTY PLUMBING', 'OTHER VIOLATIONS',
#        'ILLEGAL DUMPING - CONTAINER', 'ILLEGAL DUMPING - PROPERTY',
#        'INSTALL BATH, SHOWER,BASIN, WC',
#        'COLD-WATER FAUCET FOR THE LAVATORY',
#        'HOT WATER FAUCET FOR THE LAVATORY',
#        'HOT WATER FAUCET FOR THE BATHTUB',
#        'COLD  WATER FAUCET FOR THE BATHTUB',
#        'MIXING FAUCET FOR THE KITCHEN SINK',
#        'LEAKING TRAP ON THE KITCHEN SINK', 'LEAKING TRAP ON THE BATHTUB',
#        'LEAKING TRAP ON THE LAVATORY BASIN', 'VENT FOR THE LAVATORY BASIN',
#        'LEAKING WASHERS ON THE KITCHEN SINK',
#        'LEAKING WASHERS ON THE LAVATORY BASIN',
#        'LEAKING WASHERS ON THE BATHTUB', 'CRACKED FLUSH WATER CLOSET TANK',
#        'CRACKED FLUSH WATER CLOSET BASE', 'DEFECTIVE FLUSH “L”',
#        'DEFECTIVE FIXTURES IN THE FLUSH WTR TANK',
#        'PRESSURE RELIEF/  WATER HEATER',
#        'DRAIN LINE /PRESSURE RELIEF VALVE / WTR',
#        'PAN UNDER THE WATER HEATER', 'WATER HEATER INSTALLED',
#        'DEFECTIVE WATER HEATER', 'UNSTOP THE DRAIN ON THE KITCHEN SINK',
#        'UNSTOP THE DRAIN ON THE LAVATORY BASIN',
#        'UNSTOP THE DRAIN ON THE BATHTUB', 'UNSTOP THE DRAIN ON THE SHOWER',
#        'UNSTOP THE DRAIN / FLUSH WATER CLOSET',
#        'DAMAGED FLUSH WATER CLOSET SEAT', 'DAMAGED BUILDING DRAIN',
#        'EXTEND THE VENTS A MINIMUM OF 6”', 'DEFECTIVE SUMP PUMP',
#        'TRAP FOR THE WASHING MACHINE DRAIN',
#        'CONNECT WASHING MACHINE DRAIN',
#        'BROKEN TOP ON THE FLUSH WATER CLOSET',
#        'MISSING TOP ON THE FLUSH WATER CLOSET',
#        'DAMAGED OR LEAKING AERATOR SPRAYER',
#        'DAMAGED PLUMBING WATER SUPPLY LINES',
#        'DAMAGED COUNTER TOP WORK SURFACE',
#        'OUTSIDE WATER FAUCET HANDLE AND FIXTURE',
#        'DAMAGED CLEAN OUT PLUG ON SEWER LINE',
#        'DAMAGED DRAIN LINES UNDER THE HOUSE',
#        'VENT TO THE OUTSIDE FOR THE DRYER',
#        'FAUCETS FOR THE WASHING MACHINE',
#        'UNSTOP THE WASHING MACHINE DRAIN',
#        'RE-SECURE THE WATER CLOSET TO THE FLOOR',
#        'VENT FOR THE WATER CLOSET', 'OTHER PLUMBING DEFECTS',
#        'EXHAUST FAN', 'PLUMBING EMPLOYEE FACILITIES', 'ROOF LEAKING',
#        'RAISE SAGGING ROOF TO ORIGINAL POSITION',
#        'REPLACE ENTIRE ROOF COVERING', 'MISSING AND DEFECTIVE SIDING',
#        'EXTERIOR (BRICK VENEER-STONE) WALLS',
#        'DAMAGED (FRONT OR REAR) PORCH CEILING', 'OVERHAUL PORCH OR STEPS',
#        'CONCRETE PORCH AND STEPS',
#        'CORNICES, EAVES, STAIRS, PORCH COLUMNS',
#        'ROTTED OR DEFECTIVE SHEATHING, RAFTERS',
#        'MORTAR JOINTS OF CHIMNEYS, MISSING BRICK',
#        'UNSAFE PARTS OF CHIMNEY', 'BROKEN WINDOW GLASS',
#        'OVERHAUL WINDOWS', 'SCREENS FOR ALL WINDOWS AND DOORS',
#        'DAMAGED SCREENS', 'MISSING DOWNSPOUTS',
#        'RUSTED AND DEFECTIVE GUTTERS DOWNSPOUTS',
#        'UNDERPINNING, HATCHWAY, EXTERIOR DOORS', 'PAINT EXTERIOR',
#        'EXTERIOR PAINT', 'DAMAGED INTERIOR WALLS, CEILINGS, FLOORS',
#        'CLEAN FINISH FOR ALL WALLS CEILINGS DOOR',
#        'BROKEN, LOOSE AND MISSING PLASTER', 'CEILING: LOOSE AND MISSING',
#        'ROTTED, MISSING OR DEFECTIVE FLOORING', 'RAISE AND LEVEL FLOORS',
#        'SAND AND REFINISH FLOOR SURFACES', 'FLOOR COVERING', 'HANDRAILS',
#        'BANISTER SECURING HANDRAIL', 'BROKEN AND WOOD STAIR TREADS',
#        'DAMAGED INTERIOR DOOR', 'MISSING HARDWARE', 'OVERHAUL FRAME',
#        'RODENTS, INFESTATION AND VERMIN', 'REGULATION GARBAGE CONTAINER',
#        'YARD AREA', 'REPAIR FENCES, SHEDS, GARAGES',
#        'REMOVE DILAPIDATED FENCES, SHED, GARAGE', 'REMOVE JUNK',
#        'REMOVE COMBUSTIBLE MATERIAL', 'FAILURE TO REPAIR',
#        'PROHIBITED SIGN - HARMFUL', 'APPROVED GARBAGE & TRASH CONTAINERS',
#        'ACCUMUALTION OF GARBAGE & TRASH',
#        'ACCUMUALTION OF LUMBER, BOXES, BARRELS',
#        'STAGNANT WATER COLLECTION', 'DIRT, FILTH, RUBBISH & GARBAGE',
#        'VERMIN AND RODENT INFESTATION', 'CLEAN AMINAL AREAS',
#        'IMPROPER MAINT SEWAGE DISPOSAL SYSTEM', 'VERMIN',
#        'VEGETATION VIOLATION', 'STRP Permit Required', 'Excess Bedrooms',
#        'Owner Occupied Permit Violation', 'Signage Prohibited',
#        'Excessive Noise / Waste', 'RV - Campers, Buses Prohibited',
#        'Food Provided Prohibited', 'Excess Occupancy',
#        'Occupancy Time Limits', 'Sales without a permit',
#        'Off Sale - consume on or near premises',
#        'On sale required for on premise consume', 'Caterer Permit',
#        'Special Event - sales on premises',
#        'Owners convict beer laws moral turpitude',
#        'Owners incarcerated moral turpitude',
#        'Supplemental Application Information',
#        'False statement on application', 'Payment of Privilege Tax',
#        'BB public place', 'BB invoices and memos', 'BB permit display',
#        'BB Off Sale permit display', 'BB permit address displayed',
#        'On sale permit issuance requirements',
#        'Caterer Advanced Notice of events',
#        'Caterer location revoked on sale permit',
#        'Caterer in 100 feet of church or school',
#        'Liquor sales to under 21', 'BB prohibited drugs on premises',
#        'BB beverage in excess of 8 percent', 'BB possession under 21',
#        'BB Employ any person convicted', 'BB Employ any person released',
#        'BB sell to under 21 years', 'BB sell between 3am-6am',
#        'BB under 18 loiter', 'BB false statement application',
#        'BB operate disorderly place', 'BB unlawful passing to minor',
#        'BB sell for passing to minor', 'BB disorderly conduct',
#        'BB unauthorized transfer', 'BB sale to intoxicated',
#        'BB intoxicated loiter', 'BB delivery 11pm-3am',
#        'BB unauthorized storage', 'BB no sale using food stamps',
#        'BB gambling or gambling device', 'BB solicitation prostitution',
#        'BB criminal activity', 'Detriment public health, safety, morals',
#        'Unlawful transport, sell, etc. beer',
#        'BB wholesaler sales restriction',
#        'BB purchase unauthorized wholesaler',
#        'BB retail sales and storage location', 'BB delivery location',
#        'BB unauthorized resale redelivery',
#        'BB resale from unauthorized wholesale',
#        'BB beer permit not returned', 'BB single location',
#        'BB operating name on application',
#        'BB cannot transfer to another owner',
#        'BB same building multiple business', 'BB on and off sales permit',
#        'BB caterer permit each site', 'BB hotel motel locked in-room',
#        'BB hotel motel minors', 'BB WMD multiple locations',
#        'BB WMD contiguous locations', 'BB WMD transport',
#        'Permit suspension and revocation',
#        'BB improper attire employ sales', 'BB improper attire employ',
#        'BB encourage improper touch',
#        'Devices which simulate improper attire',
#        'BB Simulation of sexual activity',
#        '18 inches above and 6 feet from patron',
#        'BB devices wich simulate sexual activity',
#        'BB publicly expose genitals or anus',
#        'Film, pics, reproductions depicting acts',
#        'Not Manufacturer and Wholesale Retail',
#        'Not Wholesale and Manufacturer Retail',
#        'Operating without county city permit',
#        'Permits to citizen legal resident', 'Permit to business owner',
#        'Cannot transfer ownership', 'Permit for single location only',
#        'Business Name same as Permit Name',
#        'Two businesses one location one permit',
#        'On Sale Off Sale one permit',
#        'Return within 15 days of termination',
#        'No valid cert to sell, dist, manufacture',
#        'Resale cert not displayed distributed',
#        'Sales near schools, churches', 'No sales to minors',
#        'Law violations by owners in past 10 yrs',
#        'Employee law violations in past 10 yrs',
#        'Onsale permit for on premise consumption',
#        'Hotel motel locked in room units',
#        'Hotel motel no under 21 get keys', 'Bond required',
#        'Bond rider required', 'Bond revocation',
#        'Homemade Beer Compensation', 'Homemade Beer Sales',
#        'Homemade Beer exceed gallon limit',
#        'Homemade Beer not identified as homemade',
#        'Homemade Beer Exhibition', 'Homemade Beer Contests',
#        'Homemade Beer Contest Fees',
#        'Homemade Beer Storage on permitted site', 'Flavored Beer labeling',
#        'Indicating flavored beer product',
#        'Purchase from unauthorized seller',
#        'Invoice and memoranda keeping', 'Documentation kept for 2 years',
#        'Failure to permit inspection',
#        'State law requires ID for sale of beer', 'Sales between 12-6',
#        'Minors loitering', 'Vendor under 21 sign posted',
#        'Only 1 outdoor sign', 'Beer stored at other address',
#        'Wholesaler transfer written notice',
#        'Wholesale transfer without approval',
#        'Supplier coerce wholesaler agreement', 'Supplier coerce delivery',
#        'Supplier withhold delivery', 'Supplier cannot require brand sales',
#        'Suppler require conditions or limits',
#        'Suppler require financial information',
#        'Supplier require advertising', 'Supplier require termination',
#        'Supplier retailatory action', 'Supplier threaten cancel credit',
#        'Wholesaler written notice', 'Wholesaler transfer supplier consent',
#        'Written consent required',
#        'Wholesaler transfer to felony conviction',
#        'Wholesale transfer to revoked suspended',
#        'Wholesaler transfer bankruptcy',
#        'Wholesaler previous agreement cancelled',
#        'Supplier unreasonable delay transfer',
#        'Supplier delay consent to transfer',
#        'Responsbile Vendor clerk serve minor', 'Revoke Responsible Vendor',
#        'Revoke Res Vendor 2 violations 12 months', 'Failure to pay',
#        'Possession of Contraband', 'Dist exempt not meet reqmts',
#        'Application false statement', 'Draft Beer Keg', 'Distance',
#        'Post laws and regulations', 'Temp License Allowed',
#        'Commercially sealed containers',
#        'Under 18 transport, sell, dispense', 'No drive-through service',
#        'Special Event bonafide charity political',
#        'All owners and partners', 'No delivery', 'Permittee responsible',
#        'Lease or Ownership required', 'All applicants over 21',
#        'Ascertaining age', 'Special Event Approvals',
#        'Payment Types Accepted', 'Crimes of moral turpitude',
#        'Health Department', 'Fire Marshal', 'Surrender permits',
#        'Complaints filed in writing', 'Old or New Location',
#        'Applications 10 days prior', 'Cannot surrender to avoid penalties',
#        'Cannot temporary permits with complaints', 'Grandfathered',
#        'Expanded premises', 'Caterer Permits', 'Standard penalties',
#        'Past violations considered', 'LLC equals corporation',
#        'No motions for reconsideration', 'Special Event Permits',
#        'Suspension Rules', 'Deny permit after 6 months',
#        'No permit issued with complaints', 'Sports Authority Facilities'], dtype=object)

# %%
violations_section = pd.read_csv("../data/violations_section.csv")
violations_TCA = pd.read_csv("../data/violations_TCA.csv")
violations_MCL = pd.read_csv("../data/violations_MCL.csv")
violations_description_id = pd.read_csv("../data/violations_description_id.csv")
violations_remainder = pd.read_csv("../data/violations_remainder.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-d7a484950cbd> in <module>()
# ----> 1 violations_section = pd.read_csv("../data/violations_section.csv")
#       2 violations_TCA = pd.read_csv("../data/violations_TCA.csv")
#       3 violations_MCL = pd.read_csv("../data/violations_MCL.csv")
#       4 violations_description_id = pd.read_csv("../data/violations_description_id.csv")
#       5 violations_remainder = pd.read_csv("../data/violations_remainder.csv")
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'../data/violations_section.csv' does not exist
