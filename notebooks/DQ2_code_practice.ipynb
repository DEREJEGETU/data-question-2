# %%
import pandas as pd 
import matplotlib as mpl 
import numpy as np 
import matplotlib.pyplot as plt

# %%
##uploading the excel file
codes_violations = pd.read_excel("Codes' List of Violations 15 aug 2017.xlsx")

# %%
#Finding the info for the file
codes_violations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 15 columns):
# VIOLATION_ID      928 non-null object
# ORG_ID            789 non-null object
# VIOLATION_TYPE    788 non-null object
# VIOLATION_DESC    925 non-null object
# VIOLATION_TEXT    666 non-null object
# REMEDIAL_TEXT     345 non-null object
# TABLE_NAME        137 non-null datetime64[ns]
# EXPIRED_FLAG      651 non-null object
# DATE_EXPIRED      2 non-null object
# CREATED_BY        650 non-null float64
# DATE_CREATED      651 non-null object
# MODIFIED_BY       23 non-null object
# DATE_MODIFIED     22 non-null datetime64[ns]
# FEE_SETUP_ID      0 non-null float64
# Unnamed: 14       0 non-null float64
# dtypes: datetime64[ns](2), float64(3), object(10)
# memory usage: 109.5+ KB

# %%
#looking at the head of the file
codes_violations.head()
# Out:
#   VIOLATION_ID ORG_ID VIOLATION_TYPE                  VIOLATION_DESC  \
# 0            1      1        BANNERS                         Banners
# 1            2      1     BGMATOWNER  Proper Maintenance Req - Owner
# 2            4      1      BLDGMAINT          Proper Maintenance Req
# 3            5      1     BLDGPERMIT        Building Permit Required
# 4            6      1      BLDGSCOPE          Scope of Building Code
#
#                                       VIOLATION_TEXT     REMEDIAL_TEXT  \
# 0  Section 17.32.060 & 17.32.070 -  Banners: Bann...      CAAZ_BANNERS
# 1  Section 16.16.030 (B) - Proper maintenance req...  CAAH_BG_MATOWNER
# 2  Section 16.16.030 (A) - Proper maintenance req...   CAAH_BLDG_MAINT
# 3  Section 16.28.010 - Building Permit Required: ...  CAAB_BLDG_PERMIT
# 4  Section 16.16.020 (B) - The provisions of this...   CAAH_BLDG_SCOPE
#
#   TABLE_NAME EXPIRED_FLAG DATE_EXPIRED  CREATED_BY  \
# 0        NaT            N          NaN         1.0
# ...

# %%
#looking at the total table
codes_violations
# Out:
#                                           VIOLATION_ID            ORG_ID  \
# 0                                                    1                 1
# 1                                                    2                 1
# 2                                                    4                 1
# 3                                                    5                 1
# 4                                                    6                 1
# 5                                                    7                 1
# 6                                                    8                 1
# 7                                                    9                 1
# 8                                                   10                 1
# 9                                                   11                 1
# 10                                                  12                 1
# 11                                                  13                 1
# ...

# %%
codes_violations
# Out:
#                                           VIOLATION_ID            ORG_ID  \
# 0                                                    1                 1
# 1                                                    2                 1
# 2                                                    4                 1
# 3                                                    5                 1
# 4                                                    6                 1
# 5                                                    7                 1
# 6                                                    8                 1
# 7                                                    9                 1
# 8                                                   10                 1
# 9                                                   11                 1
# 10                                                  12                 1
# 11                                                  13                 1
# ...

# %%
# to find the unique entries in the column
codes_violations.ORG_ID.unique()
# Out:
# array([1, 'CAMCL_DUMP_DESIG', nan], dtype=object)

# %%
codes_violations.VIOLATION_DESC.unique()
# Out:
# array(['Banners', 'Proper Maintenance Req - Owner',
#        'Proper Maintenance Req', 'Building Permit Required',
#        'Scope of Building Code', 'Boarding Requirements',
#        'Boarding of Vacant Buildings', 'Vehicle In The Right-Of-Way',
#        'Certificate of Compliance Required',
#        'Certificate of Occupancy Required',
#        'Chickens and Other Domestic Farm Animals', 'Consignment Sale',
#        'Overcrowding – Unrelated Adults', 'Overcrowding – Group Home',
#        'Dumping in permitted places', 'N',
#        'Hours of Collection & Dumpster Required',
#        'Electrical System Hazards', 'Electrical System Certification',
#        'Electrical Receptacles', 'Electrical Equipment ',
#        'Electrical Lighting Fixtures', 'Electrical Facilities Required',
#        'Electrical Service Panel',
#        'Exterior Prop Area – Vehicles – Parking',
#        'Exterior Prop Area – Acces Structures',
#        'Exterior of Bldgs – Basement Hatchways',
# ...

# %%
codes_violations.VIOLATION_DESC.str.contains('Beer')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 904    False
# 905    False
# 906    False
# 907    False
# 908    False
# 909    False
# 910    False
# 911    False
# 912    False
# 913      NaN
# 914    False
# 915    False
# 916    False
# 917    False
# 918    False
# 919      NaN
# 920    False
# 921    False
# 922    False
# 923    False
# 924    False
# 925    False
# 926    False
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# 932    False
# 933    False
# Name: VIOLATION_DESC, Length: 934, dtype: object

# %%
beer = codes_violations[codes_violations.VIOLATION_DESC.str.search('Beer').index]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-3bf7d99801db> in <module>()
# ----> 1 beer = codes_violations[codes_violations.VIOLATION_DESC.str.search('Beer').index]
#
# AttributeError: 'StringMethods' object has no attribute 'search'

# %%
#if codes_violations.VIOLATION_DESC.str.contains('Beer'):
   # codes_violations['Des_Keyword'] = 'Beer'

# %%
import nltk
#nltk.download()
from nltk.tokenize import word_tokenize
from collections import Counter
from nltk.corpus import stopwords

# %%
for row in codes_violations.VIOLATION_DESC:
    row_counter = Counter(word_tokenize(str(row)))
    print(row_counter)
# Out:
# Counter({'Banners': 1})
# Counter({'Proper': 1, 'Maintenance': 1, 'Req': 1, '-': 1, 'Owner': 1})
# Counter({'Proper': 1, 'Maintenance': 1, 'Req': 1})
# Counter({'Building': 1, 'Permit': 1, 'Required': 1})
# Counter({'Scope': 1, 'of': 1, 'Building': 1, 'Code': 1})
# Counter({'Boarding': 1, 'Requirements': 1})
# Counter({'Boarding': 1, 'of': 1, 'Vacant': 1, 'Buildings': 1})
# Counter({'Vehicle': 1, 'In': 1, 'The': 1, 'Right-Of-Way': 1})
# Counter({'Certificate': 1, 'of': 1, 'Compliance': 1, 'Required': 1})
# Counter({'Certificate': 1, 'of': 1, 'Occupancy': 1, 'Required': 1})
# Counter({'Chickens': 1, 'and': 1, 'Other': 1, 'Domestic': 1, 'Farm': 1, 'Animals': 1})
# Counter({'Consignment': 1, 'Sale': 1})
# Counter({'Overcrowding': 1, '–': 1, 'Unrelated': 1, 'Adults': 1})
# Counter({'Overcrowding': 1, '–': 1, 'Group': 1, 'Home': 1})
# Counter({'Dumping': 1, 'in': 1, 'permitted': 1, 'places': 1})
# Counter({'N': 1})
# ...

# %%
for row in codes_violations.VIOLATION_DESC:
    tokens = [word for word in word_tokenize(row.lower()) if word.isalpha()]
    no_stops = [t for t in tokens if t not in stopwords.words('english')]
    row_counter = Counter(no_stops)
    print(row_counter)
# Out:
# Counter({'banners': 1})
# Counter({'proper': 1, 'maintenance': 1, 'req': 1, 'owner': 1})
# Counter({'proper': 1, 'maintenance': 1, 'req': 1})
# Counter({'building': 1, 'permit': 1, 'required': 1})
# Counter({'scope': 1, 'building': 1, 'code': 1})
# Counter({'boarding': 1, 'requirements': 1})
# Counter({'boarding': 1, 'vacant': 1, 'buildings': 1})
# Counter({'vehicle': 1})
# Counter({'certificate': 1, 'compliance': 1, 'required': 1})
# Counter({'certificate': 1, 'occupancy': 1, 'required': 1})
# Counter({'chickens': 1, 'domestic': 1, 'farm': 1, 'animals': 1})
# Counter({'consignment': 1, 'sale': 1})
# Counter({'overcrowding': 1, 'unrelated': 1, 'adults': 1})
# Counter({'overcrowding': 1, 'group': 1, 'home': 1})
# Counter({'dumping': 1, 'permitted': 1, 'places': 1})
# Counter({'n': 1})
# Counter({'hours': 1, 'collection': 1, 'dumpster': 1, 'required': 1})
# Counter({'electrical': 1, 'system': 1, 'hazards': 1})
# Counter({'electrical': 1, 'system': 1, 'certification': 1})
# ...
